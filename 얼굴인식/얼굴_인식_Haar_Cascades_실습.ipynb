# %%
#(VSCODE 버전)실습 코드 1/3
import matplotlib.pyplot as plt         # Matplotlib 라이브러리를 가져옴
from matplotlib.pyplot import imshow    # imshow 함수를 가져옴
import matplotlib.patches as patches    # 도형을 그리기 위한 patches 모듈을 가져옴
# %matplotlib inline                      
import numpy as np                      # 수학 연산을 위한 numpy 라이브러리를 가져옴
from PIL import ImageDraw               # PIL 라이브러리에서 ImageDraw 모듈을 가져옴
import PIL.Image                        # PIL에서 Image 모듈을 가져옴
from io import BytesIO                  # 바이트 스트림 처리를 위한 io 모듈의 BytesIO 클래스를 가져옴
import cv2                              # OpenCV 라이브러리를 가져옴
import operator                         # 연산자 라이브러리(operator)를 가져옴

# from google.colab import files
# from google.colab.patches import cv2_imshow

# %% [markdown]
# %matplotlib inline: 이 명령은 Jupyter Notebook 환경에서 Matplotlib 그림을 인라인으로 표시하도록 설정합니다. 코드 셀에서 그림을 생성하면 해당 그림이 코드 아래에 바로 표시됩니다.

# %%
#(VSCODE 버전) 2/3

# 이미지 업로드
uploaded_image_path = 'people-g3a6ec9fbf_1280.jpg'  # 이미지 파일 경로

# 이미지 표시
img = Image.open(uploaded_image_path)
plt.imshow(img)
plt.axis('off')  # 이미지 주위에 축 숨기기
plt.show()

# %%
#(VSCODE 버전) 3/3

# 얼굴 감지기 초기화
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# 이미지 업로드
uploaded_image_path = 'people-g3a6ec9fbf_1280.jpg'  # 이미지 파일 경로
img = cv2.imread(uploaded_image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 얼굴 감지
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=4)

# 이미지에 얼굴 주위에 사각형 그리기
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 3)

# 결과 이미지를 PIL 이미지로 변환
result_image = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# 결과 이미지 표시
plt.imshow(result_image)
plt.axis('off')  # 이미지 주위에 축 숨기기
plt.show()

print("Number of faces:", len(faces))
# Out:
# Number of faces: 5

# %%
#(코랩 버전)실습 코드 1/3
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import matplotlib.patches as patches
# %matplotlib inline
import numpy as np
from PIL import ImageDraw
import PIL.Image
from io import BytesIO
import cv2
import operator
from google.colab import files
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\designResult\softWare\pythonWorkspace\인공지능을위한머신러닝과딥러닝with파이썬_소스코드\12장\얼굴_인식_Haar_Cascades_실습.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/d%3A/designResult/softWare/pythonWorkspace/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%9D%84%EC%9C%84%ED%95%9C%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EA%B3%BC%EB%94%A5%EB%9F%AC%EB%8B%9Dwith%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%86%8C%EC%8A%A4%EC%BD%94%EB%93%9C/12%EC%9E%A5/%EC%96%BC%EA%B5%B4_%EC%9D%B8%EC%8B%9D_Haar_Cascades_%EC%8B%A4%EC%8A%B5.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> import cv2
# ...

# %%
#(코랩 버전)실습 코드 2/3
uploaded = files.upload()
uploaded = cv2.imread('people-g3a6ec9fbf_1280.jpg')
boundary = 24
im = PIL.Image.open(list(uploaded.keys())[0])
height = (im.size[1] / im.size[0]) * 20
fig=plt.subplots(figsize=(20,height))
imshow(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\designResult\softWare\pythonWorkspace\인공지능을위한머신러닝과딥러닝with파이썬_소스코드\12장\얼굴_인식_Haar_Cascades_실습.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/d%3A/designResult/softWare/pythonWorkspace/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%9D%84%EC%9C%84%ED%95%9C%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EA%B3%BC%EB%94%A5%EB%9F%AC%EB%8B%9Dwith%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%86%8C%EC%8A%A4%EC%BD%94%EB%93%9C/12%EC%9E%A5/%EC%96%BC%EA%B5%B4_%EC%9D%B8%EC%8B%9D_Haar_Cascades_%EC%8B%A4%EC%8A%B5.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> #(코랩 버전)실습 코드 2/3
# ...

# %%
#(코랩 버전)실습 코드 3/3
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +
'haarcascade_frontalface_default.xml')
img = cv2.imread(list(uploaded.keys())[0])
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 4)
for (x, y, w, h) in faces:
 cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 3)
ims = cv2.resize(img,(im.size[0],im.size[1]))
cv2_imshow(ims)
cv2.waitKey()
print("Number of faces:",len(faces))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\designResult\softWare\pythonWorkspace\인공지능을위한머신러닝과딥러닝with파이썬_소스코드\12장\얼굴_인식_Haar_Cascades_실습.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/d%3A/designResult/softWare/pythonWorkspace/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EC%9D%84%EC%9C%84%ED%95%9C%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%EA%B3%BC%EB%94%A5%EB%9F%AC%EB%8B%9Dwith%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%86%8C%EC%8A%A4%EC%BD%94%EB%93%9C/12%EC%9E%A5/%EC%96%BC%EA%B5%B4_%EC%9D%B8%EC%8B%9D_Haar_Cascades_%EC%8B%A4%EC%8A%B5.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +
# ...
