# %%
# 인터프리터를 주피터로 설정하고 동작시키면 됨(ctl + shift + p 누른 후, 인터프리터를 주피터로 선택)
# 실행 종료: q 입력
# pip install ultralytics

import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('..\\..\\data\\yolov8\\yolov8n.pt')

# 동영상 파일 사용시
video_path = "..\\..\\data\\yolov8\\boat.mp4"
cap = cv2.VideoCapture(video_path)

# webcam 사용시
#cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x640 3 boats, 64.6ms
# Speed: 2.9ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 55.7ms
# Speed: 2.7ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.8ms
# Speed: 0.9ms preprocess, 49.8ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 52.1ms
# Speed: 1.9ms preprocess, 52.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 47.6ms
# Speed: 1.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 50.3ms
# Speed: 0.0ms preprocess, 50.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.8ms
# Speed: 2.5ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.6ms
# Speed: 2.5ms preprocess, 50.6ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.4ms
# Speed: 2.5ms preprocess, 49.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.2ms
# Speed: 0.0ms preprocess, 50.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 53.6ms
# Speed: 1.0ms preprocess, 53.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 52.0ms
# Speed: 2.7ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.0ms
# Speed: 2.9ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.0ms
# Speed: 2.6ms preprocess, 49.0ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 51.9ms
# Speed: 0.7ms preprocess, 51.9ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 52.2ms
# Speed: 2.6ms preprocess, 52.2ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.6ms
# Speed: 2.5ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 2.7ms preprocess, 46.5ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.9ms
# Speed: 2.6ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 59.1ms
# Speed: 0.0ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.4ms
# Speed: 1.5ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 53.8ms
# Speed: 3.1ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.7ms
# Speed: 0.8ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 51.0ms
# Speed: 0.8ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.4ms
# Speed: 3.3ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 0.0ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.7ms
# Speed: 0.0ms preprocess, 46.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 40.7ms
# Speed: 2.7ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 54.9ms
# Speed: 3.0ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 52.8ms
# Speed: 0.0ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 42.2ms
# Speed: 2.4ms preprocess, 42.2ms inference, 3.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.7ms
# Speed: 2.6ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.0ms
# Speed: 0.0ms preprocess, 45.0ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 54.1ms
# Speed: 0.0ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 2.8ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.2ms
# Speed: 0.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 2.5ms preprocess, 46.5ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.7ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.7ms
# Speed: 2.6ms preprocess, 44.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.3ms
# Speed: 0.0ms preprocess, 50.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.6ms
# Speed: 0.0ms preprocess, 48.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.6ms
# Speed: 2.7ms preprocess, 46.6ms inference, 4.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.7ms preprocess, 46.4ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.9ms
# Speed: 2.7ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.6ms
# Speed: 2.7ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.5ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.6ms
# Speed: 2.7ms preprocess, 46.6ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.2ms
# Speed: 0.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.4ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.7ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 3.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.6ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.7ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.2ms
# Speed: 0.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.8ms
# Speed: 2.4ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.0ms
# Speed: 0.0ms preprocess, 45.0ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.8ms
# Speed: 2.6ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.2ms
# Speed: 2.6ms preprocess, 42.2ms inference, 4.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.5ms
# Speed: 0.0ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.6ms
# Speed: 0.4ms preprocess, 48.6ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.1ms
# Speed: 2.9ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 4.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.0ms
# Speed: 2.7ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.1ms
# Speed: 2.5ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.8ms preprocess, 50.6ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 53.5ms
# Speed: 0.0ms preprocess, 53.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.5ms preprocess, 50.6ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.7ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.7ms preprocess, 46.5ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.2ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.6ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.6ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 54.0ms
# Speed: 0.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 54.1ms
# Speed: 0.0ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.7ms
# Speed: 2.6ms preprocess, 50.7ms inference, 4.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 53.2ms
# Speed: 2.3ms preprocess, 53.2ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.6ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.5ms preprocess, 50.6ms inference, 4.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.1ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.8ms
# Speed: 2.5ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.6ms preprocess, 50.5ms inference, 4.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.2ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 3.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 45.9ms
# Speed: 2.5ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.8ms
# Speed: 0.0ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.9ms
# Speed: 2.6ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.6ms
# Speed: 2.6ms preprocess, 50.6ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.5ms
# Speed: 2.2ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.8ms
# Speed: 2.5ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 54.1ms
# Speed: 2.5ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.8ms
# Speed: 2.3ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.5ms preprocess, 46.4ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.3ms
# Speed: 1.0ms preprocess, 42.3ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 3.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 3.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.3ms
# Speed: 2.2ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.9ms
# Speed: 2.5ms preprocess, 49.9ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 54.1ms
# Speed: 0.0ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.6ms
# Speed: 2.3ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.8ms
# Speed: 2.3ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.6ms
# Speed: 2.4ms preprocess, 46.6ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.8ms
# Speed: 2.2ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.0ms
# Speed: 2.5ms preprocess, 50.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 54.0ms
# Speed: 0.0ms preprocess, 54.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 4.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.4ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.6ms preprocess, 46.5ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.3ms
# Speed: 2.2ms preprocess, 46.3ms inference, 4.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.0ms
# Speed: 2.7ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.4ms preprocess, 46.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.8ms
# Speed: 2.1ms preprocess, 47.8ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.3ms
# Speed: 2.6ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.5ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.7ms
# Speed: 2.4ms preprocess, 46.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 51.0ms
# Speed: 2.5ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.7ms
# Speed: 2.4ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 54.7ms
# Speed: 2.2ms preprocess, 54.7ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.0ms
# Speed: 2.6ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.8ms
# Speed: 2.5ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.3ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.6ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.5ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 54.9ms
# Speed: 2.2ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.3ms
# Speed: 2.6ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.5ms
# Speed: 0.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.4ms
# Speed: 2.2ms preprocess, 42.4ms inference, 3.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.7ms
# Speed: 2.6ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.2ms
# Speed: 2.5ms preprocess, 42.2ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.8ms
# Speed: 0.0ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.6ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 51.0ms
# Speed: 2.3ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.2ms
# Speed: 0.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.8ms
# Speed: 0.0ms preprocess, 44.8ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.9ms
# Speed: 2.2ms preprocess, 49.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.5ms preprocess, 50.5ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.4ms
# Speed: 2.4ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 2.3ms preprocess, 46.5ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 53.9ms
# Speed: 0.0ms preprocess, 53.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.4ms preprocess, 46.5ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 2.2ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.5ms
# Speed: 2.5ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.7ms
# Speed: 2.5ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.5ms preprocess, 46.5ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.3ms
# Speed: 2.5ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.6ms
# Speed: 2.3ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 2.6ms preprocess, 46.4ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 2.3ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 37.5ms
# Speed: 2.2ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 53.0ms
# Speed: 0.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 51.1ms
# Speed: 2.3ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.8ms
# Speed: 2.0ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.6ms
# Speed: 2.2ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 44.0ms
# Speed: 2.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 45.4ms
# Speed: 2.3ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 47.6ms
# Speed: 1.2ms preprocess, 47.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 53.7ms
# Speed: 0.0ms preprocess, 53.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 52.3ms
# Speed: 0.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 57.0ms
# Speed: 2.1ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 55.8ms
# Speed: 0.0ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 2.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 57.3ms
# Speed: 1.0ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 57.1ms
# Speed: 2.0ms preprocess, 57.1ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 68.5ms
# Speed: 2.4ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 60.6ms
# Speed: 2.8ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 57.4ms
# Speed: 1.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 61.3ms
# Speed: 0.0ms preprocess, 61.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.0ms
# Speed: 2.0ms preprocess, 49.0ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.3ms
# Speed: 0.0ms preprocess, 50.3ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 51.2ms
# Speed: 2.8ms preprocess, 51.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 47.1ms
# Speed: 1.9ms preprocess, 47.1ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.5ms
# Speed: 2.0ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 40.3ms
# Speed: 1.6ms preprocess, 40.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 42.8ms
# Speed: 2.6ms preprocess, 42.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 43.0ms
# Speed: 3.0ms preprocess, 43.0ms inference, 3.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 48.5ms
# Speed: 0.9ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 41.7ms
# Speed: 0.0ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.0ms
# Speed: 2.5ms preprocess, 49.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.7ms
# Speed: 2.0ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 38.7ms
# Speed: 2.7ms preprocess, 38.7ms inference, 12.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 47.2ms
# Speed: 2.7ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 48.1ms
# Speed: 2.1ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 41.6ms
# Speed: 0.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 4.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 38.4ms
# Speed: 0.0ms preprocess, 38.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.1ms
# Speed: 1.0ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 4.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.7ms
# Speed: 2.2ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 59.3ms
# Speed: 0.0ms preprocess, 59.3ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 51.0ms
# Speed: 2.6ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.9ms
# Speed: 0.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.3ms
# Speed: 2.0ms preprocess, 49.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.8ms
# Speed: 0.0ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 55.0ms
# Speed: 1.9ms preprocess, 55.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 4 boats, 49.2ms
# Speed: 0.0ms preprocess, 49.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 42.5ms
# Speed: 2.7ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 52.7ms
# Speed: 2.2ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 39.1ms
# Speed: 2.3ms preprocess, 39.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.4ms
# Speed: 0.0ms preprocess, 49.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 4.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 41.7ms
# Speed: 0.0ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 53.3ms
# Speed: 2.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 48.6ms
# Speed: 2.3ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.4ms
# Speed: 2.5ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.7ms
# Speed: 0.0ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.3ms
# Speed: 2.0ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.5ms
# Speed: 1.9ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.5ms
# Speed: 2.5ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 41.5ms
# Speed: 0.0ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.7ms
# Speed: 2.0ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.7ms
# Speed: 0.0ms preprocess, 49.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 8.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.5ms
# Speed: 2.4ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 48.5ms
# Speed: 2.0ms preprocess, 48.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 50.2ms
# Speed: 0.0ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 51.7ms
# Speed: 0.0ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.8ms
# Speed: 2.0ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.5ms
# Speed: 3.3ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 44.5ms
# Speed: 2.0ms preprocess, 44.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.8ms
# Speed: 2.2ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 3 boats, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.5ms
# Speed: 3.1ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.5ms
# Speed: 0.0ms preprocess, 46.5ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 47.9ms
# Speed: 0.0ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 46.0ms
# Speed: 1.9ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 43.0ms
# Speed: 2.2ms preprocess, 43.0ms inference, 3.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 48.4ms
# Speed: 1.0ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 41.6ms
# Speed: 1.2ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 48.1ms
# Speed: 0.0ms preprocess, 48.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 55.3ms
# Speed: 0.0ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 52.7ms
# Speed: 2.7ms preprocess, 52.7ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 boat, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 boats, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)

# %%
# 인터프리터를 주피터로 설정하고 동작시키면 됨(ctl + shift + p 누른 후, 인터프리터를 주피터로 선택)
# 실행 종료: q 입력
# pip install ultralytics

import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('..\\..\\data\\yolov8\\yolov8n.pt')

# 동영상 파일 사용시
video_path = "..\\..\\data\\yolov8\\영동고속도로.mp4"
cap = cv2.VideoCapture(video_path)

# webcam 사용시
# cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 car, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.3ms
# Speed: 3.6ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.4ms
# Speed: 2.6ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.1ms
# Speed: 2.8ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 0.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 3.2ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 2.7ms preprocess, 50.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 2.7ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.9ms
# Speed: 2.4ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 39.8ms
# Speed: 2.2ms preprocess, 39.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 44.2ms
# Speed: 0.0ms preprocess, 44.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 45.1ms
# Speed: 1.8ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.4ms
# Speed: 2.4ms preprocess, 43.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.7ms
# Speed: 0.9ms preprocess, 46.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 45.7ms
# Speed: 2.1ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.6ms
# Speed: 0.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 40.7ms
# Speed: 1.0ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.9ms
# Speed: 2.0ms preprocess, 39.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.9ms
# Speed: 2.1ms preprocess, 41.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 37.4ms
# Speed: 2.6ms preprocess, 37.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.3ms
# Speed: 2.3ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.2ms
# Speed: 2.6ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.4ms
# Speed: 2.5ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.7ms
# Speed: 2.5ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.6ms
# Speed: 0.0ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.4ms
# Speed: 3.0ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.2ms
# Speed: 2.7ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.2ms
# Speed: 2.5ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.2ms
# Speed: 2.5ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.6ms
# Speed: 2.6ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.6ms
# Speed: 2.8ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.2ms
# Speed: 2.5ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.1ms
# Speed: 2.2ms preprocess, 42.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 46.3ms
# Speed: 2.6ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.6ms
# Speed: 2.6ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.6ms
# Speed: 2.5ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.1ms
# Speed: 2.6ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.9ms
# Speed: 0.0ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 37.5ms
# Speed: 0.0ms preprocess, 37.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.7ms
# Speed: 2.6ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.1ms
# Speed: 2.5ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 40.9ms
# Speed: 2.6ms preprocess, 40.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.6ms
# Speed: 2.5ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.9ms
# Speed: 2.5ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.0ms
# Speed: 2.5ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.4ms
# Speed: 2.5ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.0ms
# Speed: 2.6ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.4ms
# Speed: 2.5ms preprocess, 38.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.3ms
# Speed: 2.7ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.9ms
# Speed: 0.0ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 37.9ms
# Speed: 2.6ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.1ms
# Speed: 2.6ms preprocess, 42.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.7ms
# Speed: 2.1ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 45.8ms
# Speed: 2.6ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.6ms
# Speed: 2.6ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.1ms
# Speed: 2.2ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.9ms
# Speed: 2.5ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.1ms
# Speed: 2.5ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 41.7ms
# Speed: 2.7ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 42.2ms
# Speed: 2.6ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 42.1ms
# Speed: 2.6ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.1ms
# Speed: 2.2ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 41.6ms
# Speed: 2.5ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 44.9ms
# Speed: 0.0ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 42.1ms
# Speed: 2.4ms preprocess, 42.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 45.9ms
# Speed: 0.0ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 46.3ms
# Speed: 2.6ms preprocess, 46.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 46.2ms
# Speed: 2.3ms preprocess, 46.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 49.4ms
# Speed: 0.0ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 41.5ms
# Speed: 2.8ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 42.1ms
# Speed: 2.3ms preprocess, 42.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 41.6ms
# Speed: 0.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.1ms
# Speed: 2.2ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 37.4ms
# Speed: 0.5ms preprocess, 37.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.0ms
# Speed: 2.4ms preprocess, 38.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.1ms
# Speed: 2.4ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 41.5ms
# Speed: 0.6ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 40.4ms
# Speed: 2.2ms preprocess, 40.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.5ms
# Speed: 2.9ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 43.6ms
# Speed: 0.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.6ms
# Speed: 2.4ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.1ms
# Speed: 2.3ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.6ms
# Speed: 0.6ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.5ms
# Speed: 2.3ms preprocess, 41.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.9ms
# Speed: 2.7ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.5ms
# Speed: 0.5ms preprocess, 41.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.5ms
# Speed: 2.3ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.3ms
# Speed: 3.0ms preprocess, 41.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 43.6ms
# Speed: 2.3ms preprocess, 43.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.5ms
# Speed: 2.7ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.5ms
# Speed: 2.6ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.6ms
# Speed: 2.8ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.9ms
# Speed: 0.0ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.2ms
# Speed: 0.0ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.1ms
# Speed: 0.0ms preprocess, 50.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.3ms
# Speed: 3.1ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.3ms
# Speed: 2.2ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.8ms
# Speed: 2.7ms preprocess, 41.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 54.1ms
# Speed: 0.0ms preprocess, 54.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 41.7ms
# Speed: 2.6ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.7ms
# Speed: 0.0ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.7ms
# Speed: 0.0ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.3ms
# Speed: 2.0ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 40.8ms
# Speed: 2.8ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.6ms
# Speed: 0.6ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 37.3ms
# Speed: 2.7ms preprocess, 37.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 42.3ms
# Speed: 2.4ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.8ms
# Speed: 0.7ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.1ms
# Speed: 2.1ms preprocess, 38.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.4ms
# Speed: 2.2ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.2ms
# Speed: 2.4ms preprocess, 42.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.1ms
# Speed: 2.4ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.3ms
# Speed: 2.1ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.7ms
# Speed: 0.6ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.4ms
# Speed: 2.1ms preprocess, 42.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.7ms
# Speed: 2.7ms preprocess, 45.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.3ms
# Speed: 2.2ms preprocess, 42.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 44.8ms
# Speed: 0.0ms preprocess, 44.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.6ms
# Speed: 0.7ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 42.3ms
# Speed: 2.1ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.8ms
# Speed: 2.6ms preprocess, 41.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 44.9ms
# Speed: 0.9ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 41.5ms
# Speed: 2.9ms preprocess, 41.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.8ms
# Speed: 2.2ms preprocess, 45.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 41.4ms
# Speed: 0.9ms preprocess, 41.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 44.2ms
# Speed: 0.0ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.7ms
# Speed: 0.7ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.3ms
# Speed: 0.0ms preprocess, 41.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.3ms
# Speed: 2.3ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.2ms
# Speed: 0.7ms preprocess, 38.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.4ms
# Speed: 2.2ms preprocess, 38.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.2ms
# Speed: 2.1ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 37.5ms
# Speed: 0.6ms preprocess, 37.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 42.9ms
# Speed: 0.0ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 45.0ms
# Speed: 0.0ms preprocess, 45.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 45.0ms
# Speed: 0.0ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 43.6ms
# Speed: 0.0ms preprocess, 43.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 45.5ms
# Speed: 0.0ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.9ms
# Speed: 2.2ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 42.3ms
# Speed: 2.2ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 43.7ms
# Speed: 2.5ms preprocess, 43.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.3ms
# Speed: 2.5ms preprocess, 42.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 40.5ms
# Speed: 2.3ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.8ms
# Speed: 0.6ms preprocess, 42.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.7ms
# Speed: 0.5ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.6ms
# Speed: 2.5ms preprocess, 39.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 51.6ms
# Speed: 2.9ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 47.9ms
# Speed: 0.0ms preprocess, 47.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.6ms
# Speed: 0.0ms preprocess, 42.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.8ms
# Speed: 1.0ms preprocess, 42.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 43.1ms
# Speed: 0.0ms preprocess, 43.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 43.0ms
# Speed: 1.9ms preprocess, 43.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.6ms
# Speed: 0.0ms preprocess, 42.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.4ms
# Speed: 2.0ms preprocess, 38.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.3ms
# Speed: 0.0ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 35.7ms
# Speed: 1.0ms preprocess, 35.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 27.0ms
# Speed: 0.0ms preprocess, 27.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 32.5ms
# Speed: 1.0ms preprocess, 32.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.2ms
# Speed: 0.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 28.4ms
# Speed: 1.0ms preprocess, 28.4ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 36.5ms
# Speed: 1.0ms preprocess, 36.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 37.8ms
# Speed: 2.1ms preprocess, 37.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 44.6ms
# Speed: 0.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 34.6ms
# Speed: 0.0ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.8ms
# Speed: 0.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.2ms
# Speed: 0.4ms preprocess, 37.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.8ms
# Speed: 0.0ms preprocess, 41.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.4ms
# Speed: 0.0ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 42.2ms
# Speed: 1.0ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.6ms
# Speed: 0.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.9ms
# Speed: 0.0ms preprocess, 45.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.1ms
# Speed: 0.0ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.9ms
# Speed: 0.6ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.0ms preprocess, 49.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 45.1ms
# Speed: 0.0ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.3ms
# Speed: 0.0ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 46.7ms
# Speed: 0.0ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.6ms
# Speed: 0.0ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.4ms
# Speed: 0.0ms preprocess, 37.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.3ms
# Speed: 1.2ms preprocess, 37.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 44.1ms
# Speed: 0.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.4ms
# Speed: 0.0ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.6ms
# Speed: 0.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 35.6ms
# Speed: 2.0ms preprocess, 35.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 35.4ms
# Speed: 0.0ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
